# %%
import psycopg2

# Parâmetros de conexão
dbname = 'postgres'
user = 'postgres'
password = '56789'
host = 'localhost'
port = '5432'

# Criar uma conexão
conn = psycopg2.connect(dbname=dbname,
                        user=user,
                        password=password,
                        host=host,
                        port=port)

# Criar um cursor para manipular os dados
cur = conn.cursor()

# Comandos SQL T-SQL

# Validar as alterações
conn.commit()

# Fechar o cursor e a conexão
cur.close()
conn.close()
