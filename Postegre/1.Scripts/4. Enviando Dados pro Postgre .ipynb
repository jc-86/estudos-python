# %% [markdown]
# Projeto inserindo dados Json da ANAC em banco Postgre
#
# Passos do projeto:
#
# 1 - Importar JSON como df
# 2 - Tratar os dados levando apenas colunas ["Numero_da_Ocorrencia", "Classificao_da_Ocorrencia", "Data_da_Ocorrencia", "Municipio", "UF", "Regiao", ""Nome_do_Fabricante"]
# 3 - Tirar acentos de nome de colunas
# 4 - Criar Banco de Dados e tabela
# 5 - Configurar a conexão
# 6 - Enviar dados para o Postgre
# 7 - Criar um Delete da tabela para não ter histórico
# 8 - Refatorar código
# 9 - Salvar em .py porque estamos treinando com arquivo script extensão .ipynb nas aulas
